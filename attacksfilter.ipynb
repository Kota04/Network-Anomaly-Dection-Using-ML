# %%
import random
import os
import pandas as pd

# %%
#this function creates a folder named "attacks" in the program directory.
def folder(f_name): 
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("Tthe folder could not be created!") 
folder("./attacks/")

# %%
# Headers of column
main_labels=["Flow ID","Source IP","Source Port","Destination IP","Destination Port","Protocol","Timestamp","Flow Duration","Total Fwd Packets",
   "Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets","Fwd Packet Length Max","Fwd Packet Length Min",
   "Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max","Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std",
   "Flow Bytes/s","Flow Packets/s","Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max",
   "Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags","Bwd URG Flags",
   "Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std",
   "Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count",
   "ECE Flag Count","Down/Up Ratio","Average Packet Size","Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk",
   "Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk","Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes",
   "Subflow Bwd Packets","Subflow Bwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd",
   "min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min","Idle Mean","Idle Std","Idle Max","Idle Min","Label","External IP"]
main_labels=( ",".join( i for i in main_labels ) )

# %%
attacks=["BENIGN", "Bot", "DDoS", "DoS GoldenEye", "DoS Hulk", "DoS Slowhttptest", "DoS slowloris", "FTP-Patator", "Heartbleed", "Infiltration", "PortScan", "SSH-Patator", "Web Attack  Brute Force", "Web Attack  Sql Injection", "Web Attack  XSS"]


benign=2359289

dict_attack={
"Bot":1966,
"DDoS":41835,
"DoS GoldenEye":10293,
"DoS Hulk":231073,
"DoS Slowhttptest":5499,
"DoS slowloris":5796,
"FTP-Patator":7938,
"Heartbleed":11,
"Infiltration":36,
"PortScan":158930,
"SSH-Patator":5897,
"Web Attack  Brute Force":1507,
"Web Attack  XSS":652,
"Web Attack  Sql Injection":21}

# %%
for i in dict_attack:
    a=0
    b=0
    this = open('./attacks/' + i + '.csv', 'w')
    this.write(str(main_labels) + '\n')
    benign_num=int(benign/(dict_attack[i]*(9/5)))
    with open("./CSVs/all_data.csv", "r") as file:
        while True:
            try:
                line = file.readline()
                line = line[:-1]
                k=line.split(',')
                if k[83]=='BENIGN':
                    rnd=random.randint(1,benign_num)
                    if rnd==1:
                            this.write(str(line)+'\n')
                            b+=1
                if  k[83]==i:
                    this.write(str(line)+'\n')
                    a+=1
                else:
                    continue
            except: 
                break
    this.close()
    print(i ,"file is completed\n attack:%d\n benign:%d\n\n\n " %(a,b))
# Out:
# Bot file is completed
#  attack:1966
#  benign:3592
#
#
#
# DDoS file is completed
#  attack:41835
#  benign:76463
#
#
#
# DoS GoldenEye file is completed
#  attack:10293
#  benign:18581
#
#
#
# DoS Hulk file is completed
#  attack:231073
#  benign:472046
#
#
#
# DoS Slowhttptest file is completed
#  attack:5499
#  benign:9779
#
#
#
# DoS slowloris file is completed
#  attack:5796
#  benign:10483
#
#
#
# FTP-Patator file is completed
#  attack:7938
#  benign:14165
#
#
#
# Heartbleed file is completed
#  attack:11
#  benign:19
#
#
#
# Infiltration file is completed
#  attack:36
#  benign:62
#
#
#
# PortScan file is completed
#  attack:158930
#  benign:294067
#
#
#
# SSH-Patator file is completed
#  attack:5897
#  benign:10601
#
#
#
# Web Attack  Brute Force file is completed
#  attack:0
#  benign:2722
#
#
#
# Web Attack  XSS file is completed
#  attack:0
#  benign:1151
#
#
#
# Web Attack  Sql Injection file is completed
#  attack:0
#  benign:41

# %%
df = pd.read_csv('./CSVs/all_data.csv')
# Out:
# /tmp/ipykernel_2433/878581538.py:1: DtypeWarning: Columns (83) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./CSVs/all_data.csv')

# %%
# Replace NaN values with a placeholder value
df['Label'].fillna('', inplace=True)    
# Set values based on the condition
df.loc[df['Label'].str.startswith('W'), 'Label'] = 'WebAttack'

# %%
dfs=df[df['Label']=='WebAttack']
dfs.info()
dfs.to_csv('./attacks/Web Attack.csv' ,index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2180 entries, 2143090 to 2223739
# Data columns (total 85 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Flow ID                      2180 non-null   int64
#  1   Source IP                    2180 non-null   int64
#  2   Source Port                  2180 non-null   float64
#  3   Destination IP               2180 non-null   int64
#  4   Destination Port             2180 non-null   float64
#  5   Protocol                     2180 non-null   float64
#  6   Timestamp                    2180 non-null   int64
#  7   Flow Duration                2180 non-null   float64
#  8   Total Fwd Packets            2180 non-null   float64
#  9   Total Backward Packets       2180 non-null   float64
#  10  Total Length of Fwd Packets  2180 non-null   float64
#  11  Total Length of Bwd Packets  2180 non-null   float64
#  12  Fwd Packet Length Max        2180 non-null   float64
#  13  Fwd Packet Length Min        2180 non-null   float64
#  14  Fwd Packet Length Mean       2180 non-null   float64
#  15  Fwd Packet Length Std        2180 non-null   float64
#  16  Bwd Packet Length Max        2180 non-null   float64
#  17  Bwd Packet Length Min        2180 non-null   float64
#  18  Bwd Packet Length Mean       2180 non-null   float64
#  19  Bwd Packet Length Std        2180 non-null   float64
#  20  Flow Bytes/s                 2180 non-null   float64
#  21  Flow Packets/s               2180 non-null   float64
#  22  Flow IAT Mean                2180 non-null   float64
#  23  Flow IAT Std                 2180 non-null   float64
#  24  Flow IAT Max                 2180 non-null   float64
#  25  Flow IAT Min                 2180 non-null   float64
#  26  Fwd IAT Total                2180 non-null   float64
#  27  Fwd IAT Mean                 2180 non-null   float64
#  28  Fwd IAT Std                  2180 non-null   float64
#  29  Fwd IAT Max                  2180 non-null   float64
#  30  Fwd IAT Min                  2180 non-null   float64
#  31  Bwd IAT Total                2180 non-null   float64
#  32  Bwd IAT Mean                 2180 non-null   float64
#  33  Bwd IAT Std                  2180 non-null   float64
#  34  Bwd IAT Max                  2180 non-null   float64
#  35  Bwd IAT Min                  2180 non-null   float64
#  36  Fwd PSH Flags                2180 non-null   float64
#  37  Bwd PSH Flags                2180 non-null   float64
#  38  Fwd URG Flags                2180 non-null   float64
#  39  Bwd URG Flags                2180 non-null   float64
#  40  Fwd Header Length            2180 non-null   float64
#  41  Bwd Header Length            2180 non-null   float64
#  42  Fwd Packets/s                2180 non-null   float64
#  43  Bwd Packets/s                2180 non-null   float64
#  44  Min Packet Length            2180 non-null   float64
#  45  Max Packet Length            2180 non-null   float64
#  46  Packet Length Mean           2180 non-null   float64
#  47  Packet Length Std            2180 non-null   float64
#  48  Packet Length Variance       2180 non-null   float64
#  49  FIN Flag Count               2180 non-null   float64
#  50  SYN Flag Count               2180 non-null   float64
#  51  RST Flag Count               2180 non-null   float64
#  52  PSH Flag Count               2180 non-null   float64
#  53  ACK Flag Count               2180 non-null   float64
#  54  URG Flag Count               2180 non-null   float64
#  55  CWE Flag Count               2180 non-null   float64
#  56  ECE Flag Count               2180 non-null   float64
#  57  Down/Up Ratio                2180 non-null   float64
#  58  Average Packet Size          2180 non-null   float64
#  59  Avg Fwd Segment Size         2180 non-null   float64
#  60  Avg Bwd Segment Size         2180 non-null   float64
#  61  Fwd Avg Bytes/Bulk           2180 non-null   float64
#  62  Fwd Avg Packets/Bulk         2180 non-null   float64
#  63  Fwd Avg Bulk Rate            2180 non-null   float64
#  64  Bwd Avg Bytes/Bulk           2180 non-null   float64
#  65  Bwd Avg Packets/Bulk         2180 non-null   float64
#  66  Bwd Avg Bulk Rate            2180 non-null   float64
#  67  Subflow Fwd Packets          2180 non-null   float64
#  68  Subflow Fwd Bytes            2180 non-null   float64
#  69  Subflow Bwd Packets          2180 non-null   float64
#  70  Subflow Bwd Bytes            2180 non-null   float64
#  71  Init_Win_bytes_forward       2180 non-null   float64
#  72  Init_Win_bytes_backward      2180 non-null   float64
#  73  act_data_pkt_fwd             2180 non-null   float64
#  74  min_seg_size_forward         2180 non-null   float64
#  75  Active Mean                  2180 non-null   float64
#  76  Active Std                   2180 non-null   float64
#  77  Active Max                   2180 non-null   float64
#  78  Active Min                   2180 non-null   float64
#  79  Idle Mean                    2180 non-null   float64
#  80  Idle Std                     2180 non-null   float64
#  81  Idle Max                     2180 non-null   float64
#  82  Idle Min                     2180 non-null   float64
#  83  Label                        2180 non-null   object
#  84  External IP                  2180 non-null   int64
# dtypes: float64(79), int64(5), object(1)
# memory usage: 1.4+ MB

# %%
##All web attack files are merged into a single file.
webs=["Web Attack  Brute Force","Web Attack  XSS","Web Attack  Sql Injection"]
for i in webs:
    df=pd.read_csv("./attacks/"+str(i)+".csv")
    df.to_csv('./attacks/Web Attack.csv' ,index = False,header=False,mode="a")
    os.remove("./attacks/"+str(i)+".csv")
