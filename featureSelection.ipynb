# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk

# %%
def folder(f_name):
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print("Error: Failed to create the directory.")

# %%
csv_files = os.listdir('./attacks/')
print(csv_files)
# Out:
# ['PortScan.csv', 'SSH-Patator.csv', 'Infiltration.csv', 'FTP-Patator.csv', 'WebAttack.csv', 'Heartbleed.csv', 'Bot.csv', 'DoS Slowhttptest.csv', 'DoS slowloris.csv', 'DoS Hulk.csv', 'DoS GoldenEye.csv', 'DDoS.csv']

# %% [markdown]
# ###### Flow ID, Source IP, Source Port, Destination IP, Destination Port,Protocol, Timestamp, External IP are not considered in the calculating the importance since attacker can generate fake IP and can attack from any port

# %%
main_labels=["Flow Duration","Total Fwd Packets",   "Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets","Fwd Packet Length Max","Fwd Packet Length Min",
   "Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max","Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std",
   "Flow Bytes/s","Flow Packets/s","Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max",
   "Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags","Bwd URG Flags",
   "Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std",
   "Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count",
   "ECE Flag Count","Down/Up Ratio","Average Packet Size","Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk",
   "Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk","Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes",
   "Subflow Bwd Packets","Subflow Bwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd",
   "min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min",
    "Idle Mean","Idle Std","Idle Max", "Idle Min","Label"]

# %%
output_folder = "./feature_pics/"
folder('./feature_pics/')

# %%
with open("importance_list_for_attack_files.csv", "w") as importance_file:

    for j in csv_files:
        df=pd.read_csv('./attacks/'+j,usecols=main_labels)
        df["Label"] = df["Label"].apply(lambda x: 1 if x == "BENIGN" else 0)
        y = df["Label"].values
        x = df.drop(["Label"], axis=1)
        X=np.float32(x)
        # Ensuring proper data types
        X[np.isnan(X)] = 0
        X[np.isinf(X)] = 0
        ## Training the model
        forest = RandomForestRegressor(n_estimators=250,random_state=0)
        forest.fit(X,y)
        ## Calculating Feature Importance
        importances = forest.feature_importances_
        std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
        indices = np.argsort(importances)[::-1]
        ## Top 20 features
        top_features = pd.DataFrame({
            'Features': df.columns[indices[:20]],
            'Importance': importances[indices[:20]]
        }).sort_values('Importance', ascending=False).set_index('Features')



        ## For plotting the graph
        plt.figure(figsize=(10, 5))
        top_features.plot(kind='bar')
        plt.title(f"{j[:-4]} Attack - Feature Importance")
        plt.ylabel('Importance')
        plt.savefig(f"{output_folder}{j[:-4]}.pdf", bbox_inches='tight', format='pdf')
        plt.close()

        top_5_features = top_features.head(5).index.tolist()
        importance_line = f"{j[:-4]}={top_5_features}\n"
        importance_file.write(importance_line)

        print(f"{j[:-4]} importance list:")
        print(top_features.head(20), "\n")
# Out:
# PortScan importance list:
#                              Importance
# Features
# Subflow Fwd Bytes              0.362820
# Flow Bytes/s                   0.313770
# Total Length of Fwd Packets    0.304197
# PSH Flag Count                 0.008403
# Bwd Packets/s                  0.001975
# Idle Min                       0.001854
# Init_Win_bytes_forward         0.001567
# Fwd Header Length              0.001142
# Fwd IAT Mean                   0.001085
# Flow IAT Max                   0.000551
# Fwd Packets/s                  0.000263
# Packet Length Mean             0.000259
# Init_Win_bytes_backward        0.000256
# Flow Duration                  0.000222
# Bwd IAT Max                    0.000212
# Fwd IAT Total                  0.000194
# Fwd Packet Length Max          0.000140
# Flow IAT Mean                  0.000116
# Flow Packets/s                 0.000092
# Average Packet Size            0.000075
#
# SSH-Patator importance list:
#                              Importance
# Features
# Init_Win_bytes_backward        0.985446
# Bwd Packets/s                  0.002399
# Bwd Header Length              0.001323
# Average Packet Size            0.000788
# Fwd Header Length              0.000669
# Init_Win_bytes_forward         0.000657
# Flow IAT Max                   0.000579
# min_seg_size_forward           0.000500
# Flow IAT Mean                  0.000484
# Total Length of Fwd Packets    0.000484
# Fwd Packet Length Max          0.000471
# Subflow Fwd Bytes              0.000462
# Fwd IAT Min                    0.000452
# Flow Duration                  0.000434
# Fwd Packets/s                  0.000400
# Fwd IAT Total                  0.000348
# Fwd IAT Mean                   0.000313
# Flow Packets/s                 0.000306
# Avg Fwd Segment Size           0.000290
# Flow Bytes/s                   0.000263
#
# Infiltration importance list:
#                              Importance
# Features
# Total Length of Fwd Packets    0.217742
# Subflow Fwd Bytes              0.214420
# Avg Fwd Segment Size           0.100163
# Fwd IAT Min                    0.099828
# Fwd Packet Length Mean         0.099355
# act_data_pkt_fwd               0.056540
# Flow Duration                  0.029246
# Init_Win_bytes_backward        0.019484
# ACK Flag Count                 0.015955
# Fwd IAT Total                  0.012127
# Max Packet Length              0.010919
# Packet Length Mean             0.009387
# Bwd IAT Std                    0.007470
# Average Packet Size            0.006527
# Bwd Packet Length Mean         0.006274
# Fwd Packets/s                  0.006127
# URG Flag Count                 0.006052
# Fwd Packet Length Max          0.006041
# Fwd IAT Max                    0.005655
# Flow IAT Max                   0.005362
#
# FTP-Patator importance list:
#                              Importance
# Features
# Average Packet Size            0.770683
# Fwd Packet Length Max          0.190277
# Fwd Packet Length Std          0.022854
# Packet Length Mean             0.002379
# Avg Fwd Segment Size           0.002186
# Fwd Packets/s                  0.001597
# SYN Flag Count                 0.001502
# Fwd PSH Flags                  0.001395
# min_seg_size_forward           0.001128
# Subflow Bwd Bytes              0.000564
# Init_Win_bytes_forward         0.000513
# Bwd Packet Length Mean         0.000492
# Total Length of Bwd Packets    0.000488
# Avg Bwd Segment Size           0.000449
# Packet Length Std              0.000290
# Max Packet Length              0.000259
# Bwd Packet Length Max          0.000243
# Flow IAT Min                   0.000234
# Init_Win_bytes_backward        0.000218
# Bwd Packets/s                  0.000216
#
# WebAttack importance list:
#                              Importance
# Features
# Init_Win_bytes_backward        0.886895
# Init_Win_bytes_forward         0.029782
# Subflow Fwd Bytes              0.016259
# Fwd IAT Min                    0.015926
# Total Length of Fwd Packets    0.015737
# Fwd Header Length              0.008074
# Flow Bytes/s                   0.003723
# Flow IAT Min                   0.002137
# Bwd IAT Min                    0.001969
# Bwd Packet Length Max          0.001881
# Fwd Packet Length Max          0.001815
# Bwd Packet Length Std          0.001663
# Average Packet Size            0.001622
# Max Packet Length              0.001575
# Packet Length Mean             0.001218
# act_data_pkt_fwd               0.001097
# Flow IAT Max                   0.001092
# Fwd Packet Length Mean         0.000755
# Avg Fwd Segment Size           0.000734
# Fwd Packet Length Std          0.000555
#
# Heartbleed importance list:
#                              Importance
# Features
# Avg Bwd Segment Size              0.104
# Average Packet Size               0.092
# Total Length of Bwd Packets       0.080
# Subflow Bwd Bytes                 0.076
# Bwd Packet Length Mean            0.072
# Packet Length Std                 0.072
# Packet Length Mean                0.072
# Max Packet Length                 0.060
# Packet Length Variance            0.056
# Bwd Packet Length Max             0.056
# Subflow Fwd Bytes                 0.036
# Total Backward Packets            0.032
# act_data_pkt_fwd                  0.028
# Total Fwd Packets                 0.024
# Fwd Header Length                 0.024
# Subflow Bwd Packets               0.024
# Subflow Fwd Packets               0.020
# Bwd Packet Length Std             0.016
# Bwd Header Length                 0.016
# Flow IAT Min                      0.016
#
# Bot importance list:
#                          Importance
# Features
# Bwd Packet Length Mean     0.366561
# Avg Bwd Segment Size       0.361741
# Init_Win_bytes_forward     0.150898
# Init_Win_bytes_backward    0.025827
# Flow IAT Mean              0.024146
# Flow IAT Std               0.018983
# Flow IAT Max               0.010734
# Bwd IAT Mean               0.008393
# Flow Bytes/s               0.005210
# Bwd IAT Max                0.003712
# Flow IAT Min               0.003472
# Bwd IAT Total              0.002875
# Flow Duration              0.002508
# min_seg_size_forward       0.002475
# Average Packet Size        0.001492
# Fwd IAT Std                0.001028
# Bwd Packets/s              0.001025
# Fwd Header Length          0.000788
# Fwd IAT Max                0.000712
# Flow Packets/s             0.000695
#
# DoS Slowhttptest importance list:
#                              Importance
# Features
# Flow Packets/s                 0.638093
# Fwd Packet Length Min          0.108683
# Init_Win_bytes_backward        0.048906
# Avg Bwd Segment Size           0.040189
# Bwd Packet Length Mean         0.035581
# Down/Up Ratio                  0.033274
# Flow IAT Mean                  0.015888
# Init_Win_bytes_forward         0.015286
# min_seg_size_forward           0.013567
# Fwd IAT Min                    0.008966
# Bwd Packet Length Std          0.007190
# Fwd Packet Length Mean         0.002788
# Fwd Header Length              0.002396
# Flow IAT Min                   0.002362
# Avg Fwd Segment Size           0.002288
# Fwd Packet Length Std          0.001942
# Total Length of Bwd Packets    0.001760
# Fwd Packets/s                  0.001534
# Subflow Bwd Bytes              0.001429
# Bwd Packet Length Max          0.001401
#
# DoS slowloris importance list:
#                              Importance
# Features
# Flow IAT Mean                  0.467348
# Avg Bwd Segment Size           0.094387
# min_seg_size_forward           0.067966
# Bwd Packet Length Mean         0.066114
# Subflow Bwd Bytes              0.049383
# SYN Flag Count                 0.031010
# Fwd PSH Flags                  0.029073
# Total Length of Bwd Packets    0.026786
# Total Fwd Packets              0.023130
# Subflow Fwd Packets            0.020892
# Fwd Header Length              0.020139
# Bwd IAT Total                  0.015958
# Init_Win_bytes_forward         0.015203
# Bwd IAT Min                    0.013435
# Bwd Packets/s                  0.013111
# Init_Win_bytes_backward        0.007199
# Bwd IAT Max                    0.005331
# Bwd IAT Mean                   0.005223
# Down/Up Ratio                  0.003171
# Fwd IAT Max                    0.002518
